# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoLourencoN/desenvolvimento-de-analista/blob/main/Python_para_Analista.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Capstone Project: DataWars**

# %%
# Ordem de atividades:
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Emma', 'Frank', 'Grace', 'Henry', 'Isabella', 'Jack', 'Karen', 'Liam', 'Maria', 'Nathan', 'Olivia', 'Peter'],
    'Age': [25, 30, 45, 20, 28, 50, 32, 37, 23, 42, 29, 31, 48, 27, 36, 41],
    'Sex': ['F', 'M', 'M', 'F', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M']
}

df = pd.DataFrame(data)

# %%
# Use pandas function to get statistical information about data
df.describe()
# Out:
#              Age
# count  16.000000
# mean   34.000000
# std     9.077445
# min    20.000000
# 25%    27.750000
# 50%    31.500000
# 75%    41.250000
# max    50.000000

# %%
# Add new column 'Status' to the dataframe
df["Status"] = ['Student', 'Worker', 'Worker', 'Student', 'Student', 'Retiree', 'Worker', 'Worker', 'Student', 'Worker', 'Student', 'Worker', 'Retiree', 'Student', 'Worker', 'Worker']
df
# Out:
#         Name  Age Sex   Status
# 0      Alice   25   F  Student
# 1        Bob   30   M   Worker
# 2    Charlie   45   M   Worker
# 3      Diana   20   F  Student
# 4       Emma   28   F  Student
# 5      Frank   50   M  Retiree
# 6      Grace   32   F   Worker
# 7      Henry   37   M   Worker
# 8   Isabella   23   F  Student
# 9       Jack   42   M   Worker
# 10     Karen   29   F  Student
# 11      Liam   31   M   Worker
# 12     Maria   48   F  Retiree
# 13    Nathan   27   M  Student
# 14    Olivia   36   F   Worker
# 15     Peter   41   M   Worker

# %%
# rename column names as given
df = df.rename(columns={"Name": "Full Name", "Age": "Years Old", "Sex": "Gender"})
df
# Out:
#    Full Name  Years Old Gender   Status
# 0      Alice         25      F  Student
# 1        Bob         30      M   Worker
# 2    Charlie         45      M   Worker
# 3      Diana         20      F  Student
# 4       Emma         28      F  Student
# 5      Frank         50      M  Retiree
# 6      Grace         32      F   Worker
# 7      Henry         37      M   Worker
# 8   Isabella         23      F  Student
# 9       Jack         42      M   Worker
# 10     Karen         29      F  Student
# 11      Liam         31      M   Worker
# 12     Maria         48      F  Retiree
# 13    Nathan         27      M  Student
# 14    Olivia         36      F   Worker
# 15     Peter         41      M   Worker

# %%
# Drop row with index as 4
# Make sure do not delete extra rows than as given to drop otherwise test case will fail. In case it happen re-run all the activities from starting.
df = df.drop(df.index[4])

df
# Out:
#    Full Name  Years Old Gender   Status
# 0      Alice         25      F  Student
# 1        Bob         30      M   Worker
# 2    Charlie         45      M   Worker
# 3      Diana         20      F  Student
# 5      Frank         50      M  Retiree
# 6      Grace         32      F   Worker
# 7      Henry         37      M   Worker
# 8   Isabella         23      F  Student
# 9       Jack         42      M   Worker
# 10     Karen         29      F  Student
# 11      Liam         31      M   Worker
# 12     Maria         48      F  Retiree
# 13    Nathan         27      M  Student
# 14    Olivia         36      F   Worker
# 15     Peter         41      M   Worker

# %%
# Drop row with index as 7 and 9
df = df.drop([7,9])
df
# Out:
#    Full Name  Years Old Gender   Status
# 0      Alice         25      F  Student
# 1        Bob         30      M   Worker
# 2    Charlie         45      M   Worker
# 3      Diana         20      F  Student
# 5      Frank         50      M  Retiree
# 6      Grace         32      F   Worker
# 8   Isabella         23      F  Student
# 10     Karen         29      F  Student
# 11      Liam         31      M   Worker
# 12     Maria         48      F  Retiree
# 13    Nathan         27      M  Student
# 14    Olivia         36      F   Worker
# 15     Peter         41      M   Worker

# %%
# Drop row with Full Name 'Bob'
df = df.drop(df.loc[df["Full Name"] == "Bob"].index)

# %%
# create a new row
new_row = {'Full Name': 'Emma', 'Years Old': 28, 'Gender': 'F', 'Status': 'Student'}

# Add the new row to the DataFrame
df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
df
# Out:
#    Full Name  Years Old Gender   Status
# 0      Alice         25      F  Student
# 1    Charlie         45      M   Worker
# 2      Diana         20      F  Student
# 3      Frank         50      M  Retiree
# 4      Grace         32      F   Worker
# 5   Isabella         23      F  Student
# 6      Karen         29      F  Student
# 7       Liam         31      M   Worker
# 8      Maria         48      F  Retiree
# 9     Nathan         27      M  Student
# 10    Olivia         36      F   Worker
# 11     Peter         41      M   Worker
# 12      Emma         28      F  Student

# %%
# Add multiple rows
multi_row = {'Full Name': ['Bob','Emma','Henry','Jack'],
             'Years Old': [30,28,37,42],
            'Gender': ['M','F','M','M'],
             'Status': ['Worker','Student','Worker','Worker']}

# Add the new row to the DataFrame
df = pd.concat([df, pd.DataFrame(multi_row)], ignore_index=True)
df
# Out:
#    Full Name  Years Old Gender   Status
# 0      Alice         25      F  Student
# 1    Charlie         45      M   Worker
# 2      Diana         20      F  Student
# 3      Frank         50      M  Retiree
# 4      Grace         32      F   Worker
# 5   Isabella         23      F  Student
# 6      Karen         29      F  Student
# 7       Liam         31      M   Worker
# 8      Maria         48      F  Retiree
# 9     Nathan         27      M  Student
# 10    Olivia         36      F   Worker
# 11     Peter         41      M   Worker
# 12      Emma         28      F  Student
# 13       Bob         30      M   Worker
# 14      Emma         28      F  Student
# 15     Henry         37      M   Worker
# 16      Jack         42      M   Worker

# %%
Filter_Data = df.loc[(df["Gender"] == "F") & (df["Status"] == "Student") & (df["Years Old"] > 20)]

# %%
Filter_Data.shape
# Out:
# (5, 4)

# %%
Filter_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Full Name  5 non-null      object
#  1   Years Old  5 non-null      int64
#  2   Gender     5 non-null      object
#  3   Status     5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 200.0+ bytes

# %%
Filter_Data.describe()
# Out:
#        Years Old
# count    5.00000
# mean    26.60000
# std      2.50998
# min     23.00000
# 25%     25.00000
# 50%     28.00000
# 75%     28.00000
# max     29.00000

# %%
df.plot(kind="line",x="Full Name",y="Years Old")
# Out:
# <Axes: xlabel='Full Name'>

# %%
df["Gender"].value_counts().plot(kind="bar", color=["pink","blue"])
# Out:
# <Axes: xlabel='Gender'>

# %%
df["Gender"].value_counts().plot(kind="pie", autopct="%1.1F%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # **PANDAS - KAGGLE**

# %% [markdown]
# Creating, Reading and Writing

# %%
"""
 Criar um DataFrame:
#pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})

 Para adicionar/renomear linhas do DF:
#pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]}, *index=['Product A', 'Product B'])*

 Criar uma série:
#pd.Series([1, 2, 3, 4, 5])

 Para dar mais detalhes:
#pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')

 Para ler um arquivo pelo Pandas:
#wine_reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv")
 **Declarar uma variável, colocar a função do pd e adicionar o DF**
pd.read_csv() possui 30 parametros opcionais.

wine_reviews.shape para ver linhas, colunas.

wine_reviews.head() para ver os 5 primeiras linhas
"""

# %% [markdown]
# Indexing, Selecting & Assigning

# %%
"""
Apenas "df(o dataframe)" para exibir

Podemos acessar a propriedade da tabela chamando ela após o "." Exemplo: reviews.country ou reviews['country']
#Para acessar o valor direto pela forma de dicionário seria: reviews['country'][0]

Procurando por posição baseada em número é: iloc | Ex.: reviews.iloc[0]
#loc e iloc pesquisam pela linha primeiro (linha, coluna). No entanto para puxar todas as linhas e apenas uma coluna seria: reviews.iloc[:, 0]
#reviews.iloc [:3,0] (de 1 até 2, igual o 'for') | é possível passar uma lista também: reviews.iloc[[0,1,2], 0] | o valor negativo representaria as últimas linhas, assim como suas colunas.

Procurando por label baseado em caracteres é: loc | Ex.: reviews.loc[0,'Country']
#Através dele é possível puxar exatamente o que deseja, como a maioria dos dataset tem seus significados, é possível: reviews.loc[:,['taster_name','taster_twitter_handle','points']]
#Em uma seleção de [0:100], enquanto o iloc iria retornar 100, o loc iria retornar 101. Neste caso o loc teria que ser [0:99]

É possível colocar uma coluna como index principal, usando: reviews.set_index("Title")

Também podemos usar uma seleção condicional: reviews.country == 'Italy' (0: True, 1: False, ...)
#Neste caso, para retornar apenas Italia, usariamos: reviews.loc[reviews.country == 'Italy']
#Tem como também usar as regras de E/OU, exemplo E: reviews.loc[(reviews.country=='Italy') & (reviews.points >= 90)], caso fosse OU seria com "|"

Há como utilizar uma função de "está em". Exemplo: reviews.country.isin(['Italy', 'France'])
#Outra aplicação é o isnull OU notnull. évazio | nãovazio. Exemplo: reviews.loc[reviews.price.notnull()] # Retornam as linhas que não tem o preço vazio

Para criar outra coluna na DF basta fazer: reviews['ctitic'] = 'everyone'
#Tem como iterar na criação. Exemplo: reviews['index_aocontrario'] = range(len(reviews), 0, -1)
"""

# %% [markdown]
# Summary Functions and Maps

# %%
"""
Para ver uma descrição geral, utilizamos: reviews.points.describe() #Retorna as descrições de pontos como contagem, média etc
Quando a coluna é com string ela retorna como: contagem, único, topo, frequência
É possível ver a informação direta usando, por exemplo, reviews.points.mean()

Para ver uma lista de valores únicos e quanto ele aparece, podemos utilizar value_counts().
Como: reviews.taster_name.value_counts()

map() serve para mapear os valores de um critério, exemplo: review_points_mean = reviews.points.mean() #Declarar uma variável com a média da coluna
reviews.points.map(lambda p: p - revie_points_mean) | Ele só aceita apenas um único valor para as series

aplly() é o metódo equivalante para transformar um DF todo em uma linha customizada, exemplo: pegar os pontos de cada linha e fazer menos a média do review_points_mean
Eles não alteram a DF original. O - pode ser tanto de subtração, quanto um concat ao ser "-", exemplo: reviews.country + " - " + reviews.region_1
"""

# %% [markdown]
# Agrupando e Ordenando

# %%
"""
groupby() para agrupar uma coluna inteira. Exemplo: reviews.groupby('points').points.count() | Todos os pontos e quantas vezes ele aparece.
O que foi feito acima é exatamente o que o atalho value_counts() faz.

Agora podemos utilizar o groupby não apenas para contar, mas para retornar o minimo, máximo, média etc.
Há como concatenar também, uma forma que existe é:
reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
ficaria: winery | 1+1=3 /\ 1+1=3 NV Rosé Sparkling (Cava)

É possível agrupar mais de uma coluna, exemplo: reviews.groupby(['country', 'province']).apply(lambad df: df.loc[df.points.idxmax()])
No código acima ele vai retornar o máximo de pontos de cada província do seu respectivo país.

Outro metódo é usar o agg(), neste metódo vai retornar diferentes funções no DF simultaneamente.
Exemplo: reviews.groupby(['country']).price.agg([len, min, max])
# Vai retornar o tamanho, minimo e máximo dos preços de cada país.

Multi-indexes é declarar uma variável que manipula alguma coluna/resultado específico. ( exemplo: countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len]) )
Para retornar os valores de index em cada linha, basta fazer o metódo .reset_index() na variável MultiIndex criado.

Para ordenar os valores basta utilizar sort_values(by="len"). Exemplo: countries_reviewed.sort_values("len") | Ordena naturalmente por crescente, para ordenar como descrecente basta: (..., ascending=False)
Para ordenar pelo index, basta usar: sort_index()
Há como ordernar mais de uma coluna, exemplo: countries_reviewed.sort_values(by=["country","len"])

"""

# %% [markdown]
# Tipo de dado e valores faltantes.

# %%
"""
Para ver o tipo de uma coluna, basta usar: .dtype | Exemplo: reviews.price.dtype #Retorna dtype('float64')
Para ver todos os tipos basta fazer: reviews.dtypes

Para substituir o tipo de dado, usamos astype('tipo_desejado') | Exemplo: reviews.points.astype('float64') | antes era int64.
O index de DF ou Series tem sua própria dtype também.

pd.isnull() ou pd.notnull() são metódos específicos do panda para procurar o vazio/não vazio de uma coluna. Utilizamos:
reviews[pd.isnull(reviews.country)] | Retorna a DF inteira com os valores vazios da coluna "country".

fillna() serve para preencher todos os vazios. Exemplo: reviews.country.fillna("Unknown")

Para substituir, utilizamos o replace(). Exemplo: reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino") | antes, depois
"""

# %% [markdown]
# Renomeando e Combinando

# %%
"""
Para renomear nós utilizamos: reviews.*rename(COLUMNS={'points':'score'})*
Para as linhas, trocaria como reviews.*rename(INDEX={0: 'first', 1:'second'})*

Os index de colunas e linhas é possível utilizar: reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')

Para combinar podemos utilizar: concat(), join() e merge(). Dele, o merge é feito de maneira simples com join()
Concat junta as duas tabelas, uma embaixo da outra
Join junta as duas tabelas, lado a lado

Exemplo de concat:
canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")

pd.concat([canadian_youtube, british_youtube])

Exemplo de join:
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')

Em uma variável (multi-index) seria:
powerlifting_combined = powerlifting_meets.set_index("MeetID").join(powerlifting_competitors.set_index("MeetID"))

"""
# Out:
# '\nPara renomear nós utilizamos: reviews.*rename(COLUMNS={\'points\':\'score\'})*\nPara as linhas, trocaria como reviews.*rename(INDEX={0: \'first\', 1:\'second\'})*\n\nOs index de colunas e linhas é possível utilizar: reviews.rename_axis("wines", axis=\'rows\').rename_axis("fields", axis=\'columns\')\n\nPara combinar podemos utilizar: concat(), join() e merge(). Dele, o merge é feito de maneira simples com join()\nConcat junta as duas tabelas, uma embaixo da outra\nJoin junta as duas tabelas, lado a lado\n\nExemplo de concat:\ncanadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")\nbritish_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")\n\npd.concat([canadian_youtube, british_youtube])\n\nExemplo de join:\nleft = canadian_youtube.set_index([\'title\', \'trending_date\'])\nright = british_youtube.set_index([\'title\', \'trending_date\'])\n\nleft.join(right, lsuffix=\'_CAN\', rsuffix=\'_UK\')\n\nEm uma variável (multi-index) seria:\npowerlifting_combined = powe
# ...

# %% [markdown]
# # **Pandas por Alex The Analyst**

# %%
# Primeiro video ensina a ler os arquivos em pandas.
"""
Tem muitos parametros opcionais em pd.read_csv. Exemplo: df = pd.read_csv(r"...", header = None, names = ['Country','Region'])
*Ponto interessante* é necessário copioar o caminho do arquivo na pasta para ler em csv, em arquivo Excel é possível colocar a aba desejada.
pd.set_option('display.max.rows|columns', 235) -> configura o quanto você quer que exiba na DF (DataFrame)
"""

# %%
# Segundo video ensina sobre filtrar colunas e linhas em pandas.
"""
Para visualizar *apenas* basta declarar df[df['coluna'] -condição-]
Há como armazenar alguma pesquisa específico, declarando uma variável e colocando as condições.
Através dessas variavéis é possível utilizar como base/pesquisa etc.
Exemplo: país_especifico = ['Bangladesh','Brazil']
df[df[country].isin(país_específico)]
#Retorna o DataFrame com os países dentro da pesquisa de "isin (está em)" da variável país_especifico.
df[df[country].str.cointains("algumtexto")]

df.filter(items|like = ['Coluna1|Linha1','Coluna2|Linha2'], axis = 1|0) # 0 para linhas | 1 para colunas
#Retorna apenas as colunas|linhas desejadas, é possível trocar o index (ao invés de número) para alguma coluna da DF.

Para visualizar a DF ordenado, podemos usar:
df[df['Rank'] < 10].sort_values(by=['Rank','Country'], ascending = [True,False]) #! É possível deixar crescente/descrecente a coluna em questão (1,2 etc)
Retorna os 9 primeiros do DF pelo RANK, ordenado primeiro pelo RANK depois pelo PAÍS
"""

# %%
# Terceiro video ensina sobre indexar.
"""
Primeiro jeito de pesquisar: df.loc['Albania'] # Retorna todas as informações da Albania
Segundo jeito de pesquisar: df.iloc[1] # Faz exatamente o mesmo, mas usando número ao invés de país.

df.set_index(['Continent','Country'], inplace=True) # Retorna dois indexes em DF
df.sort_index() # Vai "agrupar" o continente e seus países por ordem alfabetica

df.loc['Africa','Angola'] # Pois agora tem duas indexes para ser pesquisada, se for só "Angola" não vai encontrar.
df.iloc não vai se basear no novo index, ele vai continuar procurando pelo index original da DF.
"""

# %%
# Quarto video ensina sobre Agrupar e Funções de Agregações
"""
Depois de agrupar, é possível colocar algumas agregações.

Boa prática de agrupamento é por valores únicos/repetidos, nada que tenha muitas variações.
group_flavor = df.groupby('Base Flavor') #se colocar ".mean()" vai retornar igual abaixo, porém é mais interessante deixar ele fixo no agrupado e depois acrescentar outras modificações chamando a variável criada.

Através dessa variável com o agrupamento, podemos analisar criteriosamente
group_flavor.mean() # Retorna a média nas linhas de cada coluna que é númerica
.min() ou .max() # Retornar o minimo/máximo de cada coluna para o agrupamento em questão, ou seja, o maior preço, a maior avaliação (não correspondendo exatamente a uma linha que é superior ao resto)

group_flavor.agg({"Flavor Rating":['mean,'max','count','sum'] } ) # Retorna a média, máximo, contagem e soma da coluna "Flavor Rating" tudo em uma só visualização
Como está em dicionário, é possível colocar outras tabelas "{'colunax'" e o que quer que seja mostrado ": ['a','b','c']}"

Há como agrupar duas colunas, exemplo: df.groupby(['Base Flavor', 'Liked'])
Um atalho para analisar rápido um agrupamento, pode ser usado o .describe()
"""

# %%
# Mesclando DF em pandas
"""
Combinando duas tabela diferentes em uma só.

df1.merge(df2) vai fazer um INNER JOIN  # pega apenas os valores correspondentes com a segunda tabela
se utilizarmos: df1.mrge(df2, how = 'inner', on = 'FellowshipID') vai retornar ambas tabelas lado a lado
é possível fazer uma lista em "ON", como se criasse uma chave única.

em "how = 'outer'", é criado um FULL JOIN
o mesmo serve para CROSS, LEFT e RIGHT joins.

Usando o metódo join é mais simples do que merge.
df1.join(df2, on = "FellowshipID", how = 'outer|inner', lsuffix = '_Left', rsuffix = '_Right')
PARA SIMPLIFICAR:
df4 = df1.set_index('FellowshipID').join(df2.set_index('FellowshipID'), lsuffix = '_Left', rsuffix = '_Right', how = '*tal*')

#Gostei desse:
Concat: pd.concat([df1,df2], join = 'inner', axis = 1N)
"""

# %%
# Criando visualização usando pandas

"""
import numpy as np
import matplotlib.pyplot as plt

Gráfico de linhas:
df.plot(kind = "line", title = 'Ice Cream Ratings', xlabel = 'Daily Ratings', ylabel = 'Scores') #subplots = True para ver cada gráfico

Gráfico de barras:
df['#para especificar a coluna'].plot(kind='bar', stacked = True|False)
df.plot.barh (barra horizontal)

Gráfico de pontos:
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', #s (size) e c (color)# )

Gráfico de histograma:
df.plot.hist(bins=20)

Gráfico/diagrama de caixa:
df.boxplot()

Gráfico de área:
df.plot.area(figsize = (10,5))

Gráfico de pizza:
df.plot.pie(y="Flavor Rating", figsize=(10,6))
"""

# %% [markdown]
# # **PROJETO - Limpeza de dados**

# %%
df = pd.read_excel("/content/Customer Call List.xlsx")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15334/635848424.py in <cell line: 0>()
# ----> 1 df = pd.read_excel("/content/Customer Call List.xlsx")
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df = df.drop_duplicates()
df

# %%
df = df.drop(columns = "Not_Useful_Column")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15334/536884768.py in <cell line: 0>()
# ----> 1 df = df.drop(columns = "Not_Useful_Column")
#       2 df
#
# NameError: name 'df' is not defined

# %%
df["Last_Name"] = df["Last_Name"].str.strip("123._/")
df

# %%
df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]','', regex=True)
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: str(x))
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])

df['Phone_Number'] = df['Phone_Number'].str.replace("nan--",'')
df['Phone_Number'] = df['Phone_Number'].str.replace("Na--",'')

df

# %%
df[["Street Address", "State", "Zip_Code"]] = df['Address'].str.split(",",n=2, expand=True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15334/708555520.py in <cell line: 0>()
# ----> 1 df[["Street Address", "State", "Zip_Code"]] = df['Address'].str.split(",",n=2, expand=True)
#       2 df
#
# NameError: name 'df' is not defined

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("Yes","Y")
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("No","N")
df

# %%
df = df.replace("N/a","")
df = df.replace('NaN','')

df = df.fillna('')
backup = df

# %%
for x in df.index:
  if df.loc[x, "Do_Not_Contact"] == 'Y':
    df.loc[x, 'Phone_Number'] = "Blocked"

# OU df.loc[df['Do_Not_Contact'] == 'Y', 'Phone_Number'] = 'Blocked'

df

# %%
# Filtra apenas os pagantes.
df = df[(df['Paying Customer'] != 'N') & (df['Paying Customer'] != '')]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15334/3685990197.py in <cell line: 0>()
#       1 # Filtra apenas os pagantes.
# ----> 2 df = df[(df['Paying Customer'] != 'N') & (df['Paying Customer'] != '')]
#       3 df
#
# NameError: name 'df' is not defined

# %%
# Ordeno por Contato e Reinicio o index por garantia.
df = df.sort_values(by='Do_Not_Contact', ascending = False)
df = df.reset_index(drop=True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15334/3427900965.py in <cell line: 0>()
#       1 # Ordeno por Contato e Reinicio o index por garantia.
# ----> 2 df = df.sort_values(by='Do_Not_Contact', ascending = False)
#       3 df = df.reset_index(drop=True)
#       4 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# #**Limpeza de Dados - Kaggle**

# %%
# Lidando com valores faltantes
"""
import numpy as np


# Quantos dados estão vazios?
Total faltante da DF:
missing_values_count = nfl_data.isnull().sum()
missing_values_count[0:10] -> mostra a qtd faltante nas *primeiras 10 colunas*

# Qual é o total de valores faltantes nós temos?
total_cells = np.product(nfl_data.shape)
total_missing = missing_values_count.sum()

# Porcentagem de dados faltantes
percent_missing = (total_missing/total_cells) * 100
print(percent_missing) # 24.87214126835169


# Descobrindo qual dado está vazio
missing_values_count[0:10] | Descobrir se o dado vazio ocorreu porque não foi gravado ou porque não existe?


# Removendo valores vazios
.dropna -> remove todas as linhas que contém valor vazio
para não remover tudo (porque toda dataset tem pelo menos um valor vazio) usamos:
columns_with_na_dropped = nfl_data.dropna(axis=1) -> remove todas as colunas com pelo menos 1 valor faltando

# Quantos dados nós perdemos?
print("Colunas no original dataset: %d \n" % nfl_data.shape[1])
print("Colunas com na's removidos: %d" % columns_with_na_dropped.shape[1])
# Sobrou 61 colunas.


# Preenchendo valores faltante automaticamente
subset_nfl_data = nfl_data.loc[:, 'EPA':'Season'].head() | Todas as linhas, de EPA até SEASON. Mostrar os 5 primeiros (head)
subset_nfl_data

subset_nfl_data.fillna(0) | Preenche todos os valores vazios com 0.

.bfill(axis=0|1) -> preenche os valores ausentes copiando o valor da linha de baixo (0) ou de lado (!).
"""

# %%
# Escalonamento e Normalização
"""
# Módulos utilizados:

import pandas as pd
import numpy as np
# for Box-Cox Transformation
from scipy import stats
# for min_max scaling
from mlxtend.preprocessing import minmax_scaling
# plotting modules
import seaborn as sns
import matplotlib.pyplot as plt
# set seed for reproducibility
np.random.seed(0)


# Qual é a diferença?
Escalonar = Lidando com o alcance dos dados. De acordo/conforme ele vai aumentando
Normalizar = Lidando com o tamanho da distribuição dos dados. Do jeito que estiver
Um assume que os dados podem ter variações, outro assume que está perfeitamente distribuida.
"""

# %%
# Analisando datas
"""
pandas as pd
numpy as np
seaborn as sns
datetime

print(landslides['date'].head()) # Para ter certeza que contém data.
landslides['date'].dtype # Para ter certeza que o TIPO da coluna é o tipo de data (datetime64)

# Convertendo a coluna de data para datetime
# %d para dia, %m para mês, %y para ano em dois-digitos e %Y para ano em quatro-digitos.
Exemplo:
1/17/07 tem o formato "%m/%d/%y"
17-1-2007 tem o formato "%d-%m-%Y"

Então fariamos da seguinte forma:
landslides['date_parsed'] = pd.to_datetime(landslides['date'], format="%m/%d/%y")

Caso dê erro por tratar muitas datas em uma única coluna, a alternativa é:
landslides['date_parsed'] = pd.to_datetime(landslides['Date'], infer_datetime_format=True)
Só não pode usar infer_datetime_format = True toda hora porque o pandas vai adivinhar toda a hora e causa lentidão

#Selecionando o dia do mês
Exemplo:
day_of_month_landslides = landslides['date_parsed'].dt.day
day_of_month_landslides.head()
É possível fazer isso pois criamos uma coluna que o tipo é datetime64.

#Plot para checar a data corrigida
É sempre bom fazer uma dupla-verificação antes de analisar de fato, para isso usamos:
# remove na's
day_of_month_landslides = day_of_month_landslides.dropna()

# plot the day of the month
sns.distplot(day_of_month_landslides, kde=False, bins=31)

Ao gerar o gráfico, podemos ver se os valores fazem sentido.
"""

# %%
# Character Encodings
"""
# modules we'll use
import pandas as pd
import numpy as np
# helpful character encoding module
import charset_normalizer
# set seed for reproducibility
np.random.seed(0)

Caracteres especiais podem atrapalhar a leitura, para isso fazemos:

# começa com o charactere
before = "This is the euro symbol: €"
# checa o dtype dele
type(before) # str
# encode em um diferente, substituindo caracteres que dariam erro:
after = before.encode("utf-8", errors='replace')
# checa o dtype
type(after) # bytes
after # retorna: b'This is the euro symbol: \xe2\x82\xac'
print(after.decode("utf-8")) # This is the euro symbol: €

# olha para os primeiros 10 mil bytes para adivinhar o caractere de enconding
with open("../input/kickstarter-projects/ks-projects-201801.csv", 'rb') as rawdata:
    result = charset_normalizer.detect(rawdata.read(10000))
print(result) # {'encoding': 'utf-8', 'language': 'English', 'confidence': 1.0}

o charset_normalizer está apontando que 73% do caractere certo é "Windows-1252". # Como?

# Salvando o arquivo com UTF-8 encoding
kickstarter_2016.to_csv("ks-projects-201801-utf8.csv") # é salvo como formato padrão.
"""

# %%
# Entrada de dados inconsistentes.
"""
# pega todos os valores únicos na coluna "country"
countries = professors['Country'].unique()

countries.sort()
countries

# Foi localizado que alguns tiveram espaço " " antes, depois, durante ou até sem ele em alguns textos.

#covertendo para minusculo
professors['Country'] = professor['Country'].str.lower()

#remove os espaços em branco
professors['Country'] = professor['Country'].str.strip()

#Após fazer as alterações acima, podemos:
countries = professors['Country'].unique()

#Ainda sim tem país que está com caractere tudo junto

#Para lidar com grandes quantidades, vamos utilizar fuzzywuzzy
# pega os top 10 mais próximos de "south korea"
matches = fuzzywuzzy.process.extract("south korea", countries, limit=10, scorer=fuzzywuzzy.fuzz.token_sort_ratio)

# Identificando, podemos substituir a coluna com o raio do mais próximo do nosso match.
# function to replace rows in the provided column of the provided dataframe
# that match the provided string above the provided ratio with the provided string
def replace_matches_in_column(df, column, string_to_match, min_ratio = 47):
    # get a list of unique strings
    strings = df[column].unique()

    # get the top 10 closest matches to our input string
    matches = fuzzywuzzy.process.extract(string_to_match, strings,
                                         limit=10, scorer=fuzzywuzzy.fuzz.token_sort_ratio)

    # only get matches with a ratio > 90
    close_matches = [matches[0] for matches in matches if matches[1] >= min_ratio]

    # get the rows of all the close matches in our dataframe
    rows_with_matches = df[column].isin(close_matches)

    # replace all rows with close matches with the input matches
    df.loc[rows_with_matches, column] = string_to_match

    # let us know the function's done
    print("All done!")

replace_matches_in_column(df=professors, column='Country', string_to_match="south korea")
"""

# %% [markdown]
# # **PROJETO - Análise de Dado Exploratória**

# %%
df = pd.read_csv(r"/content/world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
df.describe()
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           230.00           233.00           230.00
# mean  117.50      34632250.88      33600710.95      32066004.16
# std    67.69     137889172.44     135873196.61     131507146.34
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        406471.00        394295.00
# 50%   117.50       5762857.00       5456681.00       5244415.00
# 75%   175.75      22653719.00      21522626.00      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           227.00           227.00           229.00           229.00
# mean       30270164.48      26840495.26      19330463.93      16282884.78
# std       126074183.54     113352454.57      81309624.96      69345465.54
# min             596.00           651.00           700.00           733.00
# ...

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %%
df.sort_values(by="2022 Population", ascending=False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41     1425887337.00    1424929781.00    1393715448.00    1348191368.00
# 92     1417173173.00    1396387127.00    1322866505.00    1240613620.00
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.36            -0.36
# 2022 Population             -0.36             1.00             1.00
# 2020 Population             -0.36             1.00             1.00
# 2015 Population             -0.35             1.00             1.00
# 2010 Population             -0.35             1.00             1.00
# 2000 Population             -0.34             0.99             1.00
# 1990 Population             -0.33             0.99             0.99
# 1980 Population             -0.33             0.99             0.99
# 1970 Population             -0.34             0.97             0.98
# Area (km²)                  -0.38             0.45             0.45
# Density (per km²)            0.13            -0.03            -0.03
# Growth Rate                 -0.22            -0.02            -0.03
# World Population Percentage -0.36             1.00             1.00
#
# ...

# %%
sns.heatmap(df.corr(numeric_only=True), annot = True)

plt.show()

# %%
df.groupby('Continent').mean(numeric_only=True)
# Out:
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         92.16      25455879.68      23871435.26      21419703.57
# Asia           77.56      96327387.31      94955134.37      89165003.64
# Europe        124.50      15055371.82      14915843.92      15027454.12
# North America 160.93      15007403.40      14855914.82      14259596.25
# Oceania       188.52       2046386.32       1910148.96       1756664.48
# South America  97.57      31201186.29      30823574.50      29509599.71
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa             18898197.31      14598365.95      11376964.52
# Asia               89087770.00      80580835.11      48639995.33
# Europe             14712278.68      14817685.71      14785203.94
# North America      13568016.28      12151739.60      10531660.62
# Oceania             1613163.65       1357512.09       1162774.87
# ...

# %%
df[df['Continent'].str.contains('Oceania')]
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 3     213  ASM            American Samoa     Pago Pago   Oceania
# 11     55  AUS                 Australia      Canberra   Oceania
# 44    223  COK              Cook Islands        Avarua   Oceania
# 66    162  FJI                      Fiji          Suva   Oceania
# 70    183  PYF          French Polynesia       Papeete   Oceania
# 81    191  GUM                      Guam       Hagåtña   Oceania
# 107   192  KIR                  Kiribati        Tarawa   Oceania
# 126   215  MHL          Marshall Islands        Majuro   Oceania
# 132   194  FSM                Micronesia       Palikir   Oceania
# 142   225  NRU                     Nauru         Yaren   Oceania
# 145   185  NCL             New Caledonia        Nouméa   Oceania
# 146   123  NZL               New Zealand    Wellington   Oceania
# 150   232  NIU                      Niue         Alofi   Oceania
# ...

# %%
df2 = df.groupby('Continent').mean(numeric_only=True).iloc[:, -5:-13:-1].sort_values(by = '1970 Population', ascending = False)

# %%
df2 = df2.transpose()

# %%
df2.plot()
# Out:
# <Axes: >
